# %% [markdown]
# # Import libs

# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, Flatten, Conv1D, MaxPooling1D
from tensorflow.keras.regularizers import l2
from sklearn.metrics import roc_curve, auc
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Read data

# %%
change_df = pd.read_csv('../../datasets/group_people.csv')
bots_df = pd.read_csv('../../datasets/bots.csv')
users_df = pd.read_csv('../../datasets/users.csv')
data = pd.concat([bots_df, users_df, change_df])


source_features= ['has_photo','has_mobile','is_friend','can_post','can_see_all_posts',
            'can_see_audio','can_write_private_message','can_send_friend_request',
            'can_be_invited_group','followers_count','blacklisted','blacklisted_by_me',
            'is_favorite','is_hidden_from_feed','common_count','university','faculty',
            'graduation','relation','verified','deactivated','friend_status','can_access_closed',
            'is_closed', 'city_id','country_id','last_seen_platform','last_seen_time',
            'interests_bool', 'books_bool', 'tv_bool', 'quotes_bool', 'about_bool',
            'games_bool', 'movies_bool', 'activities_bool', 'music_bool', 'mobile_phone_bool',
            'home_phone_bool', 'site_bool', 'status_bool', 'university_bool',
            'university_name_bool', 'faculty_bool', 'faculty_name_bool', 'graduation_bool',
            'home_town_bool', 'relation_bool', 'personal_bool', 'universities_bool',
            'schools_bool', 'occupation_bool', 'education_form_bool', 'education_status_bool',
            'relation_partner_bool', 'skype_bool', 'twitter_bool', 'livejournal_bool',
            'instagram_bool', 'facebook_bool', 'facebook_name_bool', 'relatives_in_friends_bool',
            'change_nickname_bool', 'partner_in_friends_bool', 'partner_in_friends_bool',
            'posts_count', 'users_subscriptions_count', 'groups_subscriptions_count',
            'albums_count', 'audios_count', 'gifts_count', 'pages_count', 'photos_count',
            'subscriptions_count', 'videos_count', 'video_playlists_count', 'subscriptions_followers_coef',
            'subscriptions_followers_coef_norm', 'friends_count']

# %% [markdown]
# # Feature selection

# %%
X = data[source_features]
y = data['bots']

# Создаем модель линейной регрессии
X.fillna(0, inplace=True)
model = LinearRegression()

# Выполняем RFE с использованием модели линейной регрессии
selected_features_list = []
features_numbers = list(range(10, 50, 5))
for i in features_numbers:
    rfe = RFE(model, n_features_to_select=i)
    fit = rfe.fit(X, y)

    # Добавляем результаты отбора признаков
    selected_features_list.append(list(np.compress(fit.support_, source_features)))
# Out:
# /var/folders/c9/vpcgc01n1lg_15lv6_k3t_r00000gn/T/ipykernel_71290/1245993805.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.fillna(0, inplace=True)

# %% [markdown]
# # Class for collecting results

# %%
class Result:
    def __init__(self, selected_features, accuracy, precision, recall, auc, f1, fpr, tpr, roc_auc):
        self.selected_features = selected_features
        self.accuracy = accuracy
        self.precision = precision
        self.recall = recall
        self.auc = auc
        self.f1 = f1
        self.fpr = fpr
        self.tpr = tpr
        self.roc_auc = roc_auc
    
    @property
    def metrics_sum(self):
        return self.accuracy + self.precision + self.recall + self.auc + self.f1

# %% [markdown]
# # F1 score function

# %%
def f1(y_true, y_pred):
    def recall(y_true, y_pred):
        true_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true * y_pred, 0, 1)))
        possible_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true, 0, 1)))
        recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
        return recall

    def precision(y_true, y_pred):
        true_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_true * y_pred, 0, 1)))
        predicted_positives = tf.keras.backend.sum(tf.keras.backend.round(tf.keras.backend.clip(y_pred, 0, 1)))
        precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
        return precision

    precision = precision(y_true, y_pred)
    recall = recall(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+tf.keras.backend.epsilon()))

# %% [markdown]
# # Train model

# %%
# Выбираем нужные признаки и целевую переменную
results = []
for selected_features in selected_features_list:
    # Разделяем данные на обучающую и тестовую выборки
    train_data, test_data, train_labels, test_labels = train_test_split(data[selected_features], data['bots'], test_size=0.2)
    scaler = StandardScaler()
    train_data = scaler.fit_transform(train_data)
    test_data = scaler.transform(test_data)
    # Создаем модель нейронной сети
    model = tf.keras.models.Sequential([
        Dense(128, input_shape=(train_data.shape[1],), activation='relu', kernel_regularizer=l2(0.01)),
        Dropout(0.2),
        Dense(128, activation='relu', kernel_regularizer=l2(0.01)),
        Dropout(0.2),
        Dense(32, activation='relu', kernel_regularizer=l2(0.01)),
        Dropout(0.2),
        Dense(1, activation='sigmoid')
    ])

    # Компилируем модель
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'Precision', 'Recall', 'AUC', f1])

    # Обучаем модель
    history = model.fit(train_data, train_labels, epochs=9, batch_size=128, validation_data=(test_data, test_labels))

    # Оцениваем точность модели
    test_loss, test_accuracy, test_precision, test_recall, test_auc, test_f1 = model.evaluate(test_data, test_labels)

    
    # Roc кривая
    y_score = model.predict(test_data)
    y_true = test_labels

    fpr, tpr, thresholds = roc_curve(y_true, y_score)
    roc_auc = auc(fpr, tpr)
    
    
    # Создаем модель result
    result = Result(selected_features, test_accuracy, test_precision, test_recall, test_auc, test_f1, fpr, tpr, roc_auc)
    results.append(result)
# Out:
# Epoch 1/9
# 55/55 [==============================] - 10s 139ms/step - loss: 1.8840 - accuracy: 0.7289 - precision: 0.5317 - recall: 0.0573 - auc: 0.7692 - f1: 0.0703 - val_loss: 1.3211 - val_accuracy: 0.7296 - val_precision: 0.7143 - val_recall: 0.0105 - val_auc: 0.9248 - val_f1: 0.0191
# Epoch 2/9
# 55/55 [==============================] - 2s 38ms/step - loss: 1.0499 - accuracy: 0.7331 - precision: 0.8000 - recall: 0.0295 - auc: 0.8141 - f1: 0.0544 - val_loss: 0.8211 - val_accuracy: 0.7296 - val_precision: 0.7143 - val_recall: 0.0105 - val_auc: 0.9286 - val_f1: 0.0191
# Epoch 3/9
# 55/55 [==============================] - 2s 36ms/step - loss: 0.7111 - accuracy: 0.7331 - precision: 0.8000 - recall: 0.0295 - auc: 0.8176 - f1: 0.0550 - val_loss: 0.6168 - val_accuracy: 0.7296 - val_precision: 0.7143 - val_recall: 0.0105 - val_auc: 0.9144 - val_f1: 0.0191
# Epoch 4/9
# 55/55 [==============================] - 2s 36ms/step - loss: 0.5741 - accuracy: 0.7326 - precision: 0.8679 - recall: 0.0242 - auc: 0.8384 - f1: 0.0455 - val_loss: 0.5305 - val_accuracy: 0.7296 - val_precision: 0.7143 - val_recall: 0.0105 - val_auc: 0.9256 - val_f1: 0.0191
# Epoch 5/9
# 55/55 [==============================] - 2s 35ms/step - loss: 0.5143 - accuracy: 0.7662 - precision: 0.9200 - recall: 0.1573 - auc: 0.8748 - f1: 0.2520 - val_loss: 0.4904 - val_accuracy: 0.7296 - val_precision: 0.7143 - val_recall: 0.0105 - val_auc: 0.9296 - val_f1: 0.0191
# Epoch 6/9
# 55/55 [==============================] - 2s 36ms/step - loss: 0.4802 - accuracy: 0.8344 - precision: 0.9820 - recall: 0.4008 - auc: 0.9086 - f1: 0.5460 - val_loss: 0.4643 - val_accuracy: 0.7296 - val_precision: 0.7143 - val_recall: 0.0105 - val_auc: 0.9316 - val_f1: 0.0191
# Epoch 7/9
# 55/55 [==============================] - 2s 33ms/step - loss: 0.4416 - accuracy: 0.8890 - precision: 0.9870 - recall: 0.6013 - auc: 0.9349 - f1: 0.7350 - val_loss: 0.4102 - val_accuracy: 0.9311 - val_precision: 0.9890 - val_recall: 0.7553 - val_auc: 0.9677 - val_f1: 0.8552
# Epoch 8/9
# 55/55 [==============================] - 2s 34ms/step - loss: 0.3925 - accuracy: 0.9278 - precision: 0.9755 - recall: 0.7543 - auc: 0.9579 - f1: 0.8486 - val_loss: 0.3601 - val_accuracy: 0.9328 - val_precision: 0.9945 - val_recall: 0.7574 - val_auc: 0.9718 - val_f1: 0.8586
# Epoch 9/9
# 55/55 [==============================] - 2s 34ms/step - loss: 0.3524 - accuracy: 0.9400 - precision: 0.9806 - recall: 0.7959 - auc: 0.9724 - f1: 0.8784 - val_loss: 0.3319 - val_accuracy: 0.9650 - val_precision: 0.9905 - val_recall: 0.8797 - val_auc: 0.9736 - val_f1: 0.9315
# 55/55 [==============================] - 2s 38ms/step - loss: 0.3319 - accuracy: 0.9650 - precision: 0.9905 - recall: 0.8797 - auc: 0.9736 - f1: 0.9258
# 55/55 [==============================] - 0s 3ms/step
# Epoch 1/9
# 55/55 [==============================] - 6s 92ms/step - loss: 1.9215 - accuracy: 0.8148 - precision: 0.8255 - recall: 0.4080 - auc: 0.8183 - f1: 0.5351 - val_loss: 1.3105 - val_accuracy: 0.8507 - val_precision: 0.7630 - val_recall: 0.6533 - val_auc: 0.8998 - val_f1: 0.6999
# Epoch 2/9
# 55/55 [==============================] - 2s 37ms/step - loss: 1.0386 - accuracy: 0.8531 - precision: 0.8302 - recall: 0.5810 - auc: 0.8895 - f1: 0.6825 - val_loss: 0.7722 - val_accuracy: 0.8726 - val_precision: 0.8438 - val_recall: 0.6512 - val_auc: 0.9108 - val_f1: 0.7317
# Epoch 3/9
# 55/55 [==============================] - 2s 34ms/step - loss: 0.6737 - accuracy: 0.8599 - precision: 0.8414 - recall: 0.5999 - auc: 0.8925 - f1: 0.6964 - val_loss: 0.5446 - val_accuracy: 0.8726 - val_precision: 0.8702 - val_recall: 0.6237 - val_auc: 0.9098 - val_f1: 0.7217
# Epoch 4/9
# 55/55 [==============================] - 2s 35ms/step - loss: 0.5172 - accuracy: 0.8617 - precision: 0.8527 - recall: 0.5967 - auc: 0.8933 - f1: 0.6990 - val_loss: 0.4479 - val_accuracy: 0.8749 - val_precision: 0.8571 - val_recall: 0.6469 - val_auc: 0.9336 - val_f1: 0.7336
# Epoch 5/9
# 55/55 [==============================] - 2s 37ms/step - loss: 0.4496 - accuracy: 0.8629 - precision: 0.8479 - recall: 0.6067 - auc: 0.8914 - f1: 0.6995 - val_loss: 0.4034 - val_accuracy: 0.8720 - val_precision: 0.8634 - val_recall: 0.6279 - val_auc: 0.9328 - val_f1: 0.7213
# Epoch 6/9
# 55/55 [==============================] - 2s 33ms/step - loss: 0.4152 - accuracy: 0.8632 - precision: 0.8507 - recall: 0.6052 - auc: 0.8978 - f1: 0.7049 - val_loss: 0.3819 - val_accuracy: 0.8726 - val_precision: 0.8680 - val_recall: 0.6258 - val_auc: 0.9307 - val_f1: 0.7220
# Epoch 7/9
# 55/55 [==============================] - 2s 36ms/step - loss: 0.3988 - accuracy: 0.8627 - precision: 0.8514 - recall: 0.6025 - auc: 0.8950 - f1: 0.7021 - val_loss: 0.3713 - val_accuracy: 0.8731 - val_precision: 0.8684 - val_recall: 0.6279 - val_auc: 0.9329 - val_f1: 0.7234
# Epoch 8/9
# 55/55 [==============================] - 2s 34ms/step - loss: 0.3918 - accuracy: 0.8593 - precision: 0.8461 - recall: 0.5925 - auc: 0.8947 - f1: 0.6957 - val_loss: 0.3605 - val_accuracy: 0.8726 - val_precision: 0.8680 - val_recall: 0.6258 - val_auc: 0.9399 - val_f1: 0.7220
# Epoch 9/9
# 55/55 [==============================] - 2s 35ms/step - loss: 0.3822 - accuracy: 0.8637 - precision: 0.8553 - recall: 0.6030 - auc: 0.8967 - f1: 0.7029 - val_loss: 0.3562 - val_accuracy: 0.8749 - val_precision: 0.8552 - val_recall: 0.6490 - val_auc: 0.9363 - val_f1: 0.7340
# 55/55 [==============================] - 2s 37ms/step - loss: 0.3562 - accuracy: 0.8749 - precision: 0.8552 - recall: 0.6490 - auc: 0.9363 - f1: 0.7183
# 55/55 [==============================] - 0s 3ms/step
# Epoch 1/9
# 55/55 [==============================] - 6s 94ms/step - loss: 2.0052 - accuracy: 0.8184 - precision: 0.7880 - recall: 0.4563 - auc: 0.8111 - f1: 0.5800 - val_loss: 1.4015 - val_accuracy: 0.8639 - val_precision: 0.8681 - val_recall: 0.5933 - val_auc: 0.8999 - val_f1: 0.7015
# Epoch 2/9
# 55/55 [==============================] - 2s 37ms/step - loss: 1.1134 - accuracy: 0.8560 - precision: 0.8612 - recall: 0.5622 - auc: 0.8961 - f1: 0.6790 - val_loss: 0.8443 - val_accuracy: 0.8720 - val_precision: 0.8757 - val_recall: 0.6205 - val_auc: 0.9154 - val_f1: 0.7233
# Epoch 3/9
# 55/55 [==============================] - 2s 36ms/step - loss: 0.7189 - accuracy: 0.8629 - precision: 0.8698 - recall: 0.5843 - auc: 0.9042 - f1: 0.6944 - val_loss: 0.5896 - val_accuracy: 0.8772 - val_precision: 0.9369 - val_recall: 0.5912 - val_auc: 0.9165 - val_f1: 0.7209
# Epoch 4/9
# 55/55 [==============================] - 2s 37ms/step - loss: 0.5431 - accuracy: 0.8626 - precision: 0.8725 - recall: 0.5806 - auc: 0.9051 - f1: 0.6931 - val_loss: 0.4776 - val_accuracy: 0.8737 - val_precision: 0.9356 - val_recall: 0.5786 - val_auc: 0.9175 - val_f1: 0.7110
# Epoch 5/9
# 55/55 [==============================] - 2s 36ms/step - loss: 0.4611 - accuracy: 0.8620 - precision: 0.8640 - recall: 0.5859 - auc: 0.9068 - f1: 0.6962 - val_loss: 0.4227 - val_accuracy: 0.8651 - val_precision: 0.8324 - val_recall: 0.6352 - val_auc: 0.9225 - val_f1: 0.7177
# Epoch 6/9
# 55/55 [==============================] - 2s 35ms/step - loss: 0.4183 - accuracy: 0.8677 - precision: 0.8813 - recall: 0.5948 - auc: 0.9083 - f1: 0.7079 - val_loss: 0.3927 - val_accuracy: 0.8714 - val_precision: 0.9148 - val_recall: 0.5849 - val_auc: 0.9200 - val_f1: 0.7086
# Epoch 7/9
# 55/55 [==============================] - 2s 36ms/step - loss: 0.3950 - accuracy: 0.8665 - precision: 0.8758 - recall: 0.5943 - auc: 0.9103 - f1: 0.7058 - val_loss: 0.3807 - val_accuracy: 0.8743 - val_precision: 0.9418 - val_recall: 0.5765 - val_auc: 0.9256 - val_f1: 0.7107
# Epoch 8/9
# 55/55 [==============================] - 2s 33ms/step - loss: 0.3806 - accuracy: 0.8649 - precision: 0.8706 - recall: 0.5922 - auc: 0.9128 - f1: 0.7026 - val_loss: 0.3694 - val_accuracy: 0.8731 - val_precision: 0.9183 - val_recall: 0.5891 - val_auc: 0.9282 - val_f1: 0.7118
# Epoch 9/9
# 55/55 [==============================] - 2s 38ms/step - loss: 0.3757 - accuracy: 0.8669 - precision: 0.8755 - recall: 0.5964 - auc: 0.9116 - f1: 0.7043 - val_loss: 0.3670 - val_accuracy: 0.8726 - val_precision: 0.9505 - val_recall: 0.5639 - val_auc: 0.9264 - val_f1: 0.7027
# 55/55 [==============================] - 2s 38ms/step - loss: 0.3670 - accuracy: 0.8726 - precision: 0.9505 - recall: 0.5639 - auc: 0.9264 - f1: 0.6879
# 55/55 [==============================] - 0s 2ms/step
# Epoch 1/9
# 55/55 [==============================] - 8s 101ms/step - loss: 2.0452 - accuracy: 0.8229 - precision: 0.8455 - recall: 0.4312 - auc: 0.8174 - f1: 0.5663 - val_loss: 1.4029 - val_accuracy: 0.8611 - val_precision: 0.8589 - val_recall: 0.5817 - val_auc: 0.9185 - val_f1: 0.6869
# Epoch 2/9
# 55/55 [==============================] - 2s 41ms/step - loss: 1.0953 - accuracy: 0.8665 - precision: 0.8354 - recall: 0.6371 - auc: 0.9144 - f1: 0.7226 - val_loss: 0.8238 - val_accuracy: 0.8794 - val_precision: 0.8338 - val_recall: 0.6921 - val_auc: 0.9298 - val_f1: 0.7530
# Epoch 3/9
# 55/55 [==============================] - 2s 38ms/step - loss: 0.6849 - accuracy: 0.8775 - precision: 0.8432 - recall: 0.6780 - auc: 0.9270 - f1: 0.7494 - val_loss: 0.5699 - val_accuracy: 0.8794 - val_precision: 0.8304 - val_recall: 0.6964 - val_auc: 0.9327 - val_f1: 0.7516
# Epoch 4/9
# 55/55 [==============================] - 2s 41ms/step - loss: 0.5124 - accuracy: 0.8746 - precision: 0.8394 - recall: 0.6696 - auc: 0.9275 - f1: 0.7400 - val_loss: 0.4600 - val_accuracy: 0.8783 - val_precision: 0.8491 - val_recall: 0.6688 - val_auc: 0.9317 - val_f1: 0.7402
# Epoch 5/9
# 55/55 [==============================] - 2s 40ms/step - loss: 0.4321 - accuracy: 0.8779 - precision: 0.8449 - recall: 0.6780 - auc: 0.9293 - f1: 0.7479 - val_loss: 0.4066 - val_accuracy: 0.8685 - val_precision: 0.8601 - val_recall: 0.6136 - val_auc: 0.9350 - val_f1: 0.7109
# Epoch 6/9
# 55/55 [==============================] - 2s 37ms/step - loss: 0.3917 - accuracy: 0.8811 - precision: 0.8606 - recall: 0.6744 - auc: 0.9314 - f1: 0.7540 - val_loss: 0.3827 - val_accuracy: 0.8835 - val_precision: 0.8418 - val_recall: 0.7006 - val_auc: 0.9321 - val_f1: 0.7581
# Epoch 7/9
# 55/55 [==============================] - 2s 36ms/step - loss: 0.3698 - accuracy: 0.8789 - precision: 0.8483 - recall: 0.6786 - auc: 0.9324 - f1: 0.7500 - val_loss: 0.3629 - val_accuracy: 0.8869 - val_precision: 0.8531 - val_recall: 0.7028 - val_auc: 0.9359 - val_f1: 0.7678
# Epoch 8/9
# 55/55 [==============================] - 3s 62ms/step - loss: 0.3585 - accuracy: 0.8821 - precision: 0.8519 - recall: 0.6886 - auc: 0.9323 - f1: 0.7595 - val_loss: 0.3571 - val_accuracy: 0.8691 - val_precision: 0.8605 - val_recall: 0.6157 - val_auc: 0.9350 - val_f1: 0.7123
# Epoch 9/9
# 55/55 [==============================] - 4s 66ms/step - loss: 0.3483 - accuracy: 0.8788 - precision: 0.8451 - recall: 0.6817 - auc: 0.9349 - f1: 0.7518 - val_loss: 0.3492 - val_accuracy: 0.8697 - val_precision: 0.8813 - val_recall: 0.5987 - val_auc: 0.9356 - val_f1: 0.7072
# 55/55 [==============================] - 2s 39ms/step - loss: 0.3492 - accuracy: 0.8697 - precision: 0.8813 - recall: 0.5987 - auc: 0.9356 - f1: 0.6851
# 55/55 [==============================] - 0s 3ms/step
# Epoch 1/9
# 55/55 [==============================] - 7s 110ms/step - loss: 2.1748 - accuracy: 0.8169 - precision: 0.7962 - recall: 0.4449 - auc: 0.8147 - f1: 0.5648 - val_loss: 1.5263 - val_accuracy: 0.8657 - val_precision: 0.8466 - val_recall: 0.6119 - val_auc: 0.9244 - val_f1: 0.7073
# Epoch 2/9
# 55/55 [==============================] - 3s 47ms/step - loss: 1.2190 - accuracy: 0.8629 - precision: 0.8448 - recall: 0.6112 - auc: 0.9118 - f1: 0.7033 - val_loss: 0.9127 - val_accuracy: 0.8794 - val_precision: 0.8091 - val_recall: 0.7228 - val_auc: 0.9333 - val_f1: 0.7550
# Epoch 3/9
# 55/55 [==============================] - 2s 43ms/step - loss: 0.7738 - accuracy: 0.8709 - precision: 0.8404 - recall: 0.6522 - auc: 0.9229 - f1: 0.7296 - val_loss: 0.6210 - val_accuracy: 0.8829 - val_precision: 0.8571 - val_recall: 0.6780 - val_auc: 0.9376 - val_f1: 0.7497
# Epoch 4/9
# 55/55 [==============================] - 2s 43ms/step - loss: 0.5628 - accuracy: 0.8788 - precision: 0.8503 - recall: 0.6763 - auc: 0.9269 - f1: 0.7483 - val_loss: 0.4860 - val_accuracy: 0.8852 - val_precision: 0.8225 - val_recall: 0.7313 - val_auc: 0.9374 - val_f1: 0.7669
# Epoch 5/9
# 55/55 [==============================] - 2s 44ms/step - loss: 0.4625 - accuracy: 0.8824 - precision: 0.8500 - recall: 0.6925 - auc: 0.9302 - f1: 0.7620 - val_loss: 0.4162 - val_accuracy: 0.8904 - val_precision: 0.8458 - val_recall: 0.7249 - val_auc: 0.9397 - val_f1: 0.7745
# Epoch 6/9
# 55/55 [==============================] - 2s 41ms/step - loss: 0.4129 - accuracy: 0.8820 - precision: 0.8435 - recall: 0.6983 - auc: 0.9301 - f1: 0.7602 - val_loss: 0.3813 - val_accuracy: 0.8904 - val_precision: 0.8658 - val_recall: 0.7015 - val_auc: 0.9412 - val_f1: 0.7695
# Epoch 7/9
# 55/55 [==============================] - 2s 42ms/step - loss: 0.3862 - accuracy: 0.8830 - precision: 0.8545 - recall: 0.6899 - auc: 0.9294 - f1: 0.7602 - val_loss: 0.3601 - val_accuracy: 0.8886 - val_precision: 0.8362 - val_recall: 0.7292 - val_auc: 0.9407 - val_f1: 0.7725
# Epoch 8/9
# 55/55 [==============================] - 2s 43ms/step - loss: 0.3660 - accuracy: 0.8781 - precision: 0.8452 - recall: 0.6789 - auc: 0.9336 - f1: 0.7500 - val_loss: 0.3500 - val_accuracy: 0.8840 - val_precision: 0.8296 - val_recall: 0.7164 - val_auc: 0.9406 - val_f1: 0.7618
# Epoch 9/9
# 55/55 [==============================] - 2s 41ms/step - loss: 0.3574 - accuracy: 0.8838 - precision: 0.8491 - recall: 0.6999 - auc: 0.9321 - f1: 0.7666 - val_loss: 0.3385 - val_accuracy: 0.8863 - val_precision: 0.8483 - val_recall: 0.7036 - val_auc: 0.9418 - val_f1: 0.7636
# 55/55 [==============================] - 3s 46ms/step - loss: 0.3385 - accuracy: 0.8863 - precision: 0.8483 - recall: 0.7036 - auc: 0.9418 - f1: 0.7600
# 55/55 [==============================] - 0s 3ms/step
# Epoch 1/9
# 55/55 [==============================] - 9s 115ms/step - loss: 2.1989 - accuracy: 0.8155 - precision: 0.9033 - recall: 0.3633 - auc: 0.7787 - f1: 0.4987 - val_loss: 1.5248 - val_accuracy: 0.8513 - val_precision: 0.9147 - val_recall: 0.4989 - val_auc: 0.9031 - val_f1: 0.6444
# Epoch 2/9
# 55/55 [==============================] - 2s 45ms/step - loss: 1.1781 - accuracy: 0.8650 - precision: 0.8563 - recall: 0.6078 - auc: 0.9154 - f1: 0.7087 - val_loss: 0.8939 - val_accuracy: 0.8737 - val_precision: 0.8019 - val_recall: 0.7104 - val_auc: 0.9246 - val_f1: 0.7540
# Epoch 3/9
# 55/55 [==============================] - 2s 44ms/step - loss: 0.7341 - accuracy: 0.8808 - precision: 0.8499 - recall: 0.6845 - auc: 0.9292 - f1: 0.7562 - val_loss: 0.6164 - val_accuracy: 0.8754 - val_precision: 0.8249 - val_recall: 0.6871 - val_auc: 0.9246 - val_f1: 0.7492
# Epoch 4/9
# 55/55 [==============================] - 2s 42ms/step - loss: 0.5388 - accuracy: 0.8834 - precision: 0.8436 - recall: 0.7035 - auc: 0.9300 - f1: 0.7621 - val_loss: 0.4909 - val_accuracy: 0.8697 - val_precision: 0.8324 - val_recall: 0.6512 - val_auc: 0.9242 - val_f1: 0.7289
# Epoch 5/9
# 55/55 [==============================] - 2s 43ms/step - loss: 0.4456 - accuracy: 0.8837 - precision: 0.8464 - recall: 0.7014 - auc: 0.9324 - f1: 0.7638 - val_loss: 0.4312 - val_accuracy: 0.8714 - val_precision: 0.8978 - val_recall: 0.5941 - val_auc: 0.9250 - val_f1: 0.7153
# Epoch 6/9
# 55/55 [==============================] - 2s 42ms/step - loss: 0.3968 - accuracy: 0.8833 - precision: 0.8511 - recall: 0.6940 - auc: 0.9360 - f1: 0.7615 - val_loss: 0.3970 - val_accuracy: 0.8766 - val_precision: 0.8131 - val_recall: 0.7082 - val_auc: 0.9282 - val_f1: 0.7561
# Epoch 7/9
# 55/55 [==============================] - 2s 42ms/step - loss: 0.3720 - accuracy: 0.8887 - precision: 0.8596 - recall: 0.7082 - auc: 0.9366 - f1: 0.7737 - val_loss: 0.3764 - val_accuracy: 0.8737 - val_precision: 0.8186 - val_recall: 0.6871 - val_auc: 0.9286 - val_f1: 0.7454
# Epoch 8/9
# 55/55 [==============================] - 2s 41ms/step - loss: 0.3552 - accuracy: 0.8876 - precision: 0.8503 - recall: 0.7140 - auc: 0.9373 - f1: 0.7731 - val_loss: 0.3671 - val_accuracy: 0.8760 - val_precision: 0.8338 - val_recall: 0.6786 - val_auc: 0.9283 - val_f1: 0.7477
# Epoch 9/9
# 55/55 [==============================] - 2s 42ms/step - loss: 0.3470 - accuracy: 0.8879 - precision: 0.8577 - recall: 0.7066 - auc: 0.9375 - f1: 0.7729 - val_loss: 0.3598 - val_accuracy: 0.8772 - val_precision: 0.8312 - val_recall: 0.6871 - val_auc: 0.9290 - val_f1: 0.7507
# 55/55 [==============================] - 3s 45ms/step - loss: 0.3598 - accuracy: 0.8772 - precision: 0.8312 - recall: 0.6871 - auc: 0.9290 - f1: 0.7450
# 55/55 [==============================] - 0s 3ms/step
# Epoch 1/9
# 55/55 [==============================] - 8s 123ms/step - loss: 2.2470 - accuracy: 0.8186 - precision: 0.8248 - recall: 0.4176 - auc: 0.8182 - f1: 0.5449 - val_loss: 1.5854 - val_accuracy: 0.8467 - val_precision: 0.8870 - val_recall: 0.5254 - val_auc: 0.9107 - val_f1: 0.6566
# Epoch 2/9
# 55/55 [==============================] - 3s 48ms/step - loss: 1.2332 - accuracy: 0.8662 - precision: 0.8383 - recall: 0.6254 - auc: 0.9116 - f1: 0.7167 - val_loss: 0.9355 - val_accuracy: 0.8726 - val_precision: 0.8430 - val_recall: 0.6755 - val_auc: 0.9263 - val_f1: 0.7412
# Epoch 3/9
# 55/55 [==============================] - 3s 46ms/step - loss: 0.7683 - accuracy: 0.8817 - precision: 0.8499 - recall: 0.6828 - auc: 0.9239 - f1: 0.7551 - val_loss: 0.6397 - val_accuracy: 0.8766 - val_precision: 0.8310 - val_recall: 0.7079 - val_auc: 0.9289 - val_f1: 0.7569
# Epoch 4/9
# 55/55 [==============================] - 2s 45ms/step - loss: 0.5537 - accuracy: 0.8845 - precision: 0.8468 - recall: 0.6993 - auc: 0.9298 - f1: 0.7632 - val_loss: 0.5010 - val_accuracy: 0.8766 - val_precision: 0.8658 - val_recall: 0.6673 - val_auc: 0.9283 - val_f1: 0.7464
# Epoch 5/9
# 55/55 [==============================] - 2s 46ms/step - loss: 0.4531 - accuracy: 0.8851 - precision: 0.8481 - recall: 0.7003 - auc: 0.9323 - f1: 0.7645 - val_loss: 0.4353 - val_accuracy: 0.8800 - val_precision: 0.8381 - val_recall: 0.7140 - val_auc: 0.9298 - val_f1: 0.7629
# Epoch 6/9
# 55/55 [==============================] - 2s 44ms/step - loss: 0.4017 - accuracy: 0.8861 - precision: 0.8479 - recall: 0.7051 - auc: 0.9345 - f1: 0.7668 - val_loss: 0.4033 - val_accuracy: 0.8726 - val_precision: 0.8672 - val_recall: 0.6491 - val_auc: 0.9271 - val_f1: 0.7347
# Epoch 7/9
# 55/55 [==============================] - 2s 43ms/step - loss: 0.3755 - accuracy: 0.8863 - precision: 0.8530 - recall: 0.6998 - auc: 0.9350 - f1: 0.7668 - val_loss: 0.3812 - val_accuracy: 0.8812 - val_precision: 0.8629 - val_recall: 0.6897 - val_auc: 0.9300 - val_f1: 0.7581
# Epoch 8/9
# 55/55 [==============================] - 2s 45ms/step - loss: 0.3572 - accuracy: 0.8899 - precision: 0.8604 - recall: 0.7072 - auc: 0.9359 - f1: 0.7751 - val_loss: 0.3694 - val_accuracy: 0.8789 - val_precision: 0.8561 - val_recall: 0.6876 - val_auc: 0.9304 - val_f1: 0.7526
# Epoch 9/9
# 55/55 [==============================] - 2s 44ms/step - loss: 0.3462 - accuracy: 0.8881 - precision: 0.8538 - recall: 0.7072 - auc: 0.9367 - f1: 0.7727 - val_loss: 0.3599 - val_accuracy: 0.8777 - val_precision: 0.8665 - val_recall: 0.6714 - val_auc: 0.9307 - val_f1: 0.7473
# 55/55 [==============================] - 3s 50ms/step - loss: 0.3599 - accuracy: 0.8777 - precision: 0.8665 - recall: 0.6714 - auc: 0.9307 - f1: 0.7374
# 55/55 [==============================] - 0s 3ms/step
# Epoch 1/9
# 55/55 [==============================] - 9s 123ms/step - loss: nan - accuracy: 0.7296 - precision: 0.3077 - recall: 0.0021 - auc: 0.5019 - f1: 0.0027 - val_loss: nan - val_accuracy: 0.7147 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_f1: 0.0000e+00
# Epoch 2/9
# 55/55 [==============================] - 3s 48ms/step - loss: nan - accuracy: 0.7303 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5067 - f1: 0.0000e+00 - val_loss: nan - val_accuracy: 0.7147 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_f1: 0.0000e+00
# Epoch 3/9
# 55/55 [==============================] - 3s 47ms/step - loss: nan - accuracy: 0.7303 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5014 - f1: 0.0000e+00 - val_loss: nan - val_accuracy: 0.7147 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_f1: 0.0000e+00
# Epoch 4/9
# 55/55 [==============================] - 3s 46ms/step - loss: nan - accuracy: 0.7303 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.4840 - f1: 0.0000e+00 - val_loss: nan - val_accuracy: 0.7147 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_f1: 0.0000e+00
# Epoch 5/9
# 55/55 [==============================] - 3s 47ms/step - loss: nan - accuracy: 0.7303 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.4944 - f1: 0.0000e+00 - val_loss: nan - val_accuracy: 0.7147 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_f1: 0.0000e+00
# Epoch 6/9
# 55/55 [==============================] - 3s 47ms/step - loss: nan - accuracy: 0.7303 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.4993 - f1: 0.0000e+00 - val_loss: nan - val_accuracy: 0.7147 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_f1: 0.0000e+00
# Epoch 7/9
# 55/55 [==============================] - 3s 46ms/step - loss: nan - accuracy: 0.7303 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5052 - f1: 0.0000e+00 - val_loss: nan - val_accuracy: 0.7147 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_f1: 0.0000e+00
# Epoch 8/9
# 55/55 [==============================] - 3s 49ms/step - loss: nan - accuracy: 0.7303 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.4966 - f1: 0.0000e+00 - val_loss: nan - val_accuracy: 0.7147 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_f1: 0.0000e+00
# Epoch 9/9
# 55/55 [==============================] - 2s 44ms/step - loss: nan - accuracy: 0.7303 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5049 - f1: 0.0000e+00 - val_loss: nan - val_accuracy: 0.7147 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5000 - val_f1: 0.0000e+00
# 55/55 [==============================] - 4s 74ms/step - loss: nan - accuracy: 0.7147 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.5000 - f1: 0.0000e+00
# 55/55 [==============================] - 1s 13ms/step

# %% [markdown]
# # Plot graphs of metrics

# %%
# Строим график столбцов
accuracy_values = [result.accuracy for result in results]
precision_values = [result.precision for result in results]
recall_values = [result.recall for result in results]
auc_values = [result.auc for result in results]
f1_values = [result.f1 for result in results]

# Добавляем заголовок и подписи осей
fig, axs = plt.subplots(2, 2)

# Первый график
axs[0, 0].bar(features_numbers, accuracy_values, width=3)
axs[0, 0].set_title('Accuracy', fontsize=14)
axs[0, 0].set_xlabel('Number of features', fontsize=14)
axs[0, 0].set_ylabel('Value', fontsize=14)

# Второй график
axs[0, 1].bar(features_numbers, precision_values, width=3)
axs[0, 1].set_title('Precision', fontsize=14)
axs[0, 1].set_xlabel('Number of features', fontsize=14)
axs[0, 1].set_ylabel('Value', fontsize=14)

# Третий график
axs[1, 0].bar(features_numbers, recall_values, width=3)
axs[1, 0].set_title('Recall', fontsize=14)
axs[1, 0].set_xlabel('Number of features', fontsize=14)
axs[1, 0].set_ylabel('Value', fontsize=14)

# Четвертый график
axs[1, 1].bar(features_numbers, f1_values, width=3)
axs[1, 1].set_title('AUC', fontsize=14)
axs[1, 1].set_xlabel('Number of features', fontsize=14)
axs[1, 1].set_ylabel('Value', fontsize=14)

# Настраиваем расположение графиков и добавляем общий заголовок
fig.tight_layout()
fig.suptitle('MLP Metrics', fontsize=14)

# Сохраняем график
fig.set_size_inches(15.5, 10.5, forward=True)
fig.savefig('Metrics.png', dpi=300)
plt.show()

# %% [markdown]
# # Plot ROC curves

# %%
fig = plt.figure(figsize=(8, 8))

# Строим ROC кривые
for i in range(len(results)):
    plt.plot(
        results[i].fpr,
        results[i].tpr,
        label=f'ROC curve (area = %0.5f) ({len(results[i].selected_features)} features)'% results[i].roc_auc
    )

plt.plot([0, 1], [0, 1], color='grey', lw=2, linestyle='--')
plt.xlim([-0.05, 1.05])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('MLP Receiver Operating Characteristic (ROC) curves')
plt.legend(loc="lower right")

# Сохраняем график
fig.tight_layout()
plt.savefig('ROC-curves.png', dpi=300)
plt.show()
